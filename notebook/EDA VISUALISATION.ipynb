# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy

# %%
data = pd.read_csv('data/data.csv')

# %% [markdown]
# ## No of Male and Female Candidates

# %%
sns.countplot(data["SEX"])
plt.title("Female v/s Male")
plt.savefig('figure1',format="jpg")
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sex_education = (data[['SEX','EDUCATION']].query("SEX=='Female' |SEX == 'Male' ").groupby(['EDUCATION']).value_counts())

# %%
sex_education.unstack(level=0).plot(kind='bar')
plt.title("Number of Male and Female customer with repect to Education")
plt.savefig('figure2',format="jpg")

# %%
values = [data['MARRIAGE'].value_counts()[i] for i in range(len(data['MARRIAGE'].value_counts()))]
labels = ['Single','Married','Other']

colors = sns.color_palette('pastel')[0:3]
plt.pie(values, labels = labels, colors = colors, autopct='%.0f%%')
plt.title("Marital status v/s Output")
plt.savefig("figure3",format="jpg")

# %%
marriage_education = data[['MARRIAGE','EDUCATION']].groupby(['EDUCATION','MARRIAGE']).value_counts(ascending=True)

# %%
marriage_education.unstack(level=0).plot(kind='bar')
plt.title("Relation between customer Marital status and Education")
plt.savefig('figure4',format="jpg")

# %%
Education_vs_Output = data[['default#payment#next#month','EDUCATION']].groupby(['EDUCATION','default#payment#next#month']).value_counts(ascending=True)
Education_vs_Output.unstack(level=0).plot(kind="bar")
plt.title("Relation between Customer's Education and Output")
plt.savefig('figure5',format="jpg")

# %%
sum_payment_amount = data[['EDUCATION','SEX','PAY_AMT1','PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']].groupby(['EDUCATION','SEX']).sum(['PAY_AMT1','PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6'])

# %%
sum_payment_amount
# Out:
#                      PAY_AMT1    PAY_AMT2    PAY_AMT3    PAY_AMT4    PAY_AMT5  \
# EDUCATION  SEX
# High_s     Female   9154401.0   8618272.0   7641516.0   6986272.0   6945405.0
#            Male     5947570.0   5718151.0   4976546.0   4504234.0   4420738.0
# Other      Female   1124242.0   1242889.0   1097334.0    877052.0    837313.0
#            Male      750431.0    678655.0    624481.0    459548.0    442831.0
# School_g   Female  22887285.0  22834905.0  20397631.0  18640230.0  18497029.0
#            Male    17084666.0  16488509.0  14927416.0  13555931.0  13595497.0
# University Female  28770582.0  28150333.0  25363420.0  23098014.0  23368832.0
#            Male    17113983.0  16505526.0  14225454.0  13370290.0  13244994.0
#
#                      PAY_AMT6
# EDUCATION  SEX
# High_s     Female   6939057.0
#            Male     4422955.0
# Other      Female    858230.0
#            Male      432562.0
# School_g   Female  18901008.0
#            Male    13212946.0
# ...
